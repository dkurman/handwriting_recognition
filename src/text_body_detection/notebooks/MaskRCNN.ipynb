# %% [markdown]
# # Mask R-CNN Training and Inference
# In this notebook we use Matterport's implementation of Mask R-CNN to train on a custom dataset, then use the trained weights to run inference on new images.
#
# This is part of a tutorial posted at http://www.immersivelimit.com/tutorials/using-mask-r-cnn-on-custom-coco-like-dataset, so check there for more details.
#
# ### Not a beginner tutorial...
# This is not intended to be a complete beginner tutorial.
# - You should know how to clone a git repository from GitHub
# - You should have a decent understanding of Python programming
# - You should understand the basics of training deep neural networks. If you've never done it before, I wouldn't recommend starting here. Find a beginner deep learning tutorial/course and start there. There's lots of great free stuff on YouTube.
#
# ## **Download the Free Training Dataset First!
# I've provided a free training dataset of cigarette butt images for use with this tutorial.
# 1. Download it from here: http://www.immersivelimit.com/datasets/cigarette-butts
# 2. Then extract the files and put it in the "../datasets" directory of this repo
# 3. The code below will be looking for "../datasets/cig_butts/train", "../datasets/cig_butts/val", and "../datasets/cig_butts/real_test"

# %%
import os
import sys
import json
import numpy as np
import time
import skimage
from PIL import Image, ImageDraw

# %% [markdown]
# ## Import Matterport's "mrcnn" libraries
# 1. I'm using a forked version of Matterport's Mask_RCNN git repo to make sure this code works, even if the main repo changes. As of July 29, 2018, there is a bug in Matterport's version that breaks loading an existing model that I've fixed in my version (and submitted a pull request to fix it in theirs).
#   - My version is here: https://github.com/akTwelve/Mask_RCNN
#   - The original is here: https://github.com/matterport/Mask_RCNN
# 2. Update the code cell below to point to the root directory of the repo on your machine.

# %%
# Set the ROOT_DIR variable to the root directory of the Mask_RCNN git repo
#ROOT_DIR = ''
#assert os.path.exists(ROOT_DIR), 'ROOT_DIR does not exist. Did you forget to read the instructions above? ;)'

# Import mrcnn libraries
#sys.path.append(ROOT_DIR) 
from mrcnn.config import Config
import mrcnn.utils as utils
from mrcnn import visualize
import mrcnn.model as modellib
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Set up logging and pre-trained model paths
# This will default to sub-directories in your mask_rcnn_dir, but if you want them somewhere else, updated it here.
#
# It will also download the pre-trained coco model.

# %%
# Directory to save logs and trained model
MODEL_DIR = "logs"

# Local path to trained weights file
COCO_MODEL_PATH = "mask_rcnn_coco.h5"

# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)

# %% [markdown]
# ## Configuration
# Define configurations for training on the Cigarette Butt dataset.
# ### Note
# These are settings that worked on my machine (GTX 970 graphics card). If you are getting OOM (Out of Memory) errors, you may need to tweak the settings or your computer may not be powerful enough. If you have a better graphics card, you will want to tweak it to take advantage of that.

# %%
class CigButtsConfig(Config):
    """Configuration for training on the cigarette butts dataset.
    Derives from the base Config class and overrides values specific
    to the cigarette butts dataset.
    """
    # Give the configuration a recognizable name
    NAME = "coco_text"

    # Train on 1 GPU and 1 image per GPU. Batch size is 1 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

    # Number of classes (including background)
    NUM_CLASSES = 1 + 1  # background + 1 (cig_butt)

    # All of our training images are 512x512
    IMAGE_MIN_DIM = 512
    IMAGE_MAX_DIM = 512

    # You can experiment with this number to see if it improves training
    STEPS_PER_EPOCH = 500

    # This is how often validation is run. If you are using too much hard drive space
    # on saved models (in the MODEL_DIR), try making this value larger.
    VALIDATION_STEPS = 5
    
    # Matterport originally used resnet101, but I downsized to fit it on my graphics card
    BACKBONE = 'resnet50'

    # To be honest, I haven't taken the time to figure out what these do
    RPN_ANCHOR_SCALES = (8, 16, 32, 64, 128)
    TRAIN_ROIS_PER_IMAGE = 32
    MAX_GT_INSTANCES = 50 
    POST_NMS_ROIS_INFERENCE = 500 
    POST_NMS_ROIS_TRAINING = 1000 
    
config = CigButtsConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  512
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [512 512   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               50
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           coco_text
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        500
# POST_NMS_ROIS_TRAINING         1000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                500
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               5
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# # Define the dataset
# I've attempted to make this generic to any COCO-like dataset. That means if you have another dataset defined in the COCO format, it should work.

# %%
f = open('cocotext.v2.json')
data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['cats', 'anns', 'imgs', 'imgToAnns', 'info'])

# %%
data['imgs']
# Out:
# {'540965': {'id': 540965,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000540965.jpg',
#   'height': 360},
#  '229078': {'id': 229078,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000229078.jpg',
#   'height': 480},
#  '260932': {'id': 260932,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000260932.jpg',
#   'height': 512},
#  '103812': {'id': 103812,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000103812.jpg',
#   'height': 427},
#  '304937': {'id': 304937,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000304937.jpg',
#   'height': 640},
#  '558396': {'id': 558396,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000558396.jpg',
#   'height': 333},
#  '343992': {'id': 343992,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000343992.jpg',
#   'height': 424},
#  '381275': {'id': 381275,
#   'set': 'train',
#   'width': 376,
#   'file_name': 'COCO_train2014_000000381275.jpg',
#   'height': 500},
#  '422792': {'id': 422792,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000422792.jpg',
#   'height': 375},
#  '188343': {'id': 188343,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000188343.jpg',
#   'height': 359},
#  '549534': {'id': 549534,
#   'set': 'train',
#   'width': 375,
#   'file_name': 'COCO_train2014_000000549534.jpg',
#   'height': 500},
#  '425439': {'id': 425439,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000425439.jpg',
#   'height': 427},
#  '95243': {'id': 95243,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000095243.jpg',
#   'height': 480},
#  '480851': {'id': 480851,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000480851.jpg',
#   'height': 427},
#  '18466': {'id': 18466,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000018466.jpg',
#   'height': 375},
#  '70642': {'id': 70642,
#   'set': 'train',
#   'width': 612,
#   'file_name': 'COCO_train2014_000000070642.jpg',
#   'height': 612},
#  '535732': {'id': 535732,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000535732.jpg',
#   'height': 397},
#  '204714': {'id': 204714,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000204714.jpg',
#   'height': 427},
#  '265100': {'id': 265100,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000265100.jpg',
#   'height': 375},
#  '437996': {'id': 437996,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000437996.jpg',
#   'height': 480},
#  '544408': {'id': 544408,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000544408.jpg',
#   'height': 333},
#  '318223': {'id': 318223,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000318223.jpg',
#   'height': 480},
#  '578702': {'id': 578702,
#   'set': 'train',
#   'width': 478,
#   'file_name': 'COCO_train2014_000000578702.jpg',
#   'height': 640},
#  '77346': {'id': 77346,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000077346.jpg',
#   'height': 480},
#  '488379': {'id': 488379,
#   'set': 'train',
#   'width': 417,
#   'file_name': 'COCO_train2014_000000488379.jpg',
#   'height': 640},
#  '149280': {'id': 149280,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000149280.jpg',
#   'height': 480},
#  '565443': {'id': 565443,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000565443.jpg',
#   'height': 361},
#  '339589': {'id': 339589,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000339589.jpg',
#   'height': 427},
#  '266023': {'id': 266023,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000266023.jpg',
#   'height': 480},
#  '493504': {'id': 493504,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000493504.jpg',
#   'height': 375},
#  '86668': {'id': 86668,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000086668.jpg',
#   'height': 640},
#  '266496': {'id': 266496,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000266496.jpg',
#   'height': 500},
#  '427886': {'id': 427886,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000427886.jpg',
#   'height': 428},
#  '17076': {'id': 17076,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000017076.jpg',
#   'height': 480},
#  '367969': {'id': 367969,
#   'set': 'train',
#   'width': 556,
#   'file_name': 'COCO_train2014_000000367969.jpg',
#   'height': 640},
#  '316650': {'id': 316650,
#   'set': 'train',
#   'width': 436,
#   'file_name': 'COCO_train2014_000000316650.jpg',
#   'height': 640},
#  '139324': {'id': 139324,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000139324.jpg',
#   'height': 477},
#  '443883': {'id': 443883,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000443883.jpg',
#   'height': 419},
#  '223888': {'id': 223888,
#   'set': 'val',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000223888.jpg',
#   'height': 375},
#  '343526': {'id': 343526,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000343526.jpg',
#   'height': 480},
#  '528080': {'id': 528080,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000528080.jpg',
#   'height': 480},
#  '558836': {'id': 558836,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000558836.jpg',
#   'height': 480},
#  '361437': {'id': 361437,
#   'set': 'train',
#   'width': 512,
#   'file_name': 'COCO_train2014_000000361437.jpg',
#   'height': 640},
#  '408735': {'id': 408735,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000408735.jpg',
#   'height': 375},
#  '198631': {'id': 198631,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000198631.jpg',
#   'height': 640},
#  '211978': {'id': 211978,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000211978.jpg',
#   'height': 380},
#  '192497': {'id': 192497,
#   'set': 'val',
#   'width': 427,
#   'file_name': 'COCO_train2014_000000192497.jpg',
#   'height': 640},
#  '573761': {'id': 573761,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000573761.jpg',
#   'height': 428},
#  '461819': {'id': 461819,
#   'set': 'train',
#   'width': 330,
#   'file_name': 'COCO_train2014_000000461819.jpg',
#   'height': 640},
#  '546065': {'id': 546065,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000546065.jpg',
#   'height': 425},
#  '388347': {'id': 388347,
#   'set': 'train',
#   'width': 375,
#   'file_name': 'COCO_train2014_000000388347.jpg',
#   'height': 500},
#  '368040': {'id': 368040,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000368040.jpg',
#   'height': 427},
#  '485769': {'id': 485769,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000485769.jpg',
#   'height': 425},
#  '363554': {'id': 363554,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000363554.jpg',
#   'height': 640},
#  '422608': {'id': 422608,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000422608.jpg',
#   'height': 425},
#  '16725': {'id': 16725,
#   'set': 'val',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000016725.jpg',
#   'height': 375},
#  '282574': {'id': 282574,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000282574.jpg',
#   'height': 377},
#  '513550': {'id': 513550,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000513550.jpg',
#   'height': 453},
#  '463680': {'id': 463680,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000463680.jpg',
#   'height': 640},
#  '6765': {'id': 6765,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000006765.jpg',
#   'height': 427},
#  '385144': {'id': 385144,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000385144.jpg',
#   'height': 427},
#  '119922': {'id': 119922,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000119922.jpg',
#   'height': 426},
#  '351760': {'id': 351760,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000351760.jpg',
#   'height': 480},
#  '556424': {'id': 556424,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000556424.jpg',
#   'height': 427},
#  '219963': {'id': 219963,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000219963.jpg',
#   'height': 640},
#  '129859': {'id': 129859,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000129859.jpg',
#   'height': 480},
#  '562650': {'id': 562650,
#   'set': 'train',
#   'width': 612,
#   'file_name': 'COCO_train2014_000000562650.jpg',
#   'height': 612},
#  '309706': {'id': 309706,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000309706.jpg',
#   'height': 480},
#  '395321': {'id': 395321,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000395321.jpg',
#   'height': 480},
#  '316495': {'id': 316495,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000316495.jpg',
#   'height': 428},
#  '134639': {'id': 134639,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000134639.jpg',
#   'height': 426},
#  '112444': {'id': 112444,
#   'set': 'train',
#   'width': 320,
#   'file_name': 'COCO_train2014_000000112444.jpg',
#   'height': 240},
#  '4971': {'id': 4971,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000004971.jpg',
#   'height': 480},
#  '35630': {'id': 35630,
#   'set': 'train',
#   'width': 612,
#   'file_name': 'COCO_train2014_000000035630.jpg',
#   'height': 612},
#  '35529': {'id': 35529,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000035529.jpg',
#   'height': 480},
#  '129781': {'id': 129781,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000129781.jpg',
#   'height': 480},
#  '488883': {'id': 488883,
#   'set': 'train',
#   'width': 333,
#   'file_name': 'COCO_train2014_000000488883.jpg',
#   'height': 640},
#  '263764': {'id': 263764,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000263764.jpg',
#   'height': 480},
#  '461560': {'id': 461560,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000461560.jpg',
#   'height': 428},
#  '579394': {'id': 579394,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000579394.jpg',
#   'height': 413},
#  '349791': {'id': 349791,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000349791.jpg',
#   'height': 368},
#  '159400': {'id': 159400,
#   'set': 'train',
#   'width': 494,
#   'file_name': 'COCO_train2014_000000159400.jpg',
#   'height': 373},
#  '553488': {'id': 553488,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000553488.jpg',
#   'height': 427},
#  '567396': {'id': 567396,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000567396.jpg',
#   'height': 480},
#  '163442': {'id': 163442,
#   'set': 'train',
#   'width': 427,
#   'file_name': 'COCO_train2014_000000163442.jpg',
#   'height': 640},
#  '475932': {'id': 475932,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000475932.jpg',
#   'height': 487},
#  '82411': {'id': 82411,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000082411.jpg',
#   'height': 480},
#  '45186': {'id': 45186,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000045186.jpg',
#   'height': 627},
#  '391703': {'id': 391703,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000391703.jpg',
#   'height': 480},
#  '73669': {'id': 73669,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000073669.jpg',
#   'height': 427},
#  '559226': {'id': 559226,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000559226.jpg',
#   'height': 333},
#  '522185': {'id': 522185,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000522185.jpg',
#   'height': 640},
#  '155058': {'id': 155058,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000155058.jpg',
#   'height': 341},
#  '534459': {'id': 534459,
#   'set': 'train',
#   'width': 427,
#   'file_name': 'COCO_train2014_000000534459.jpg',
#   'height': 640},
#  '109199': {'id': 109199,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000109199.jpg',
#   'height': 231},
#  '287904': {'id': 287904,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000287904.jpg',
#   'height': 360},
#  '78009': {'id': 78009,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000078009.jpg',
#   'height': 480},
#  '81434': {'id': 81434,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000081434.jpg',
#   'height': 640},
#  '46630': {'id': 46630,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000046630.jpg',
#   'height': 488},
#  '363783': {'id': 363783,
#   'set': 'val',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000363783.jpg',
#   'height': 330},
#  '147505': {'id': 147505,
#   'set': 'train',
#   'width': 336,
#   'file_name': 'COCO_train2014_000000147505.jpg',
#   'height': 500},
#  '144641': {'id': 144641,
#   'set': 'val',
#   'width': 612,
#   'file_name': 'COCO_train2014_000000144641.jpg',
#   'height': 612},
#  '269862': {'id': 269862,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000269862.jpg',
#   'height': 640},
#  '43353': {'id': 43353,
#   'set': 'train',
#   'width': 612,
#   'file_name': 'COCO_train2014_000000043353.jpg',
#   'height': 612},
#  '396775': {'id': 396775,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000396775.jpg',
#   'height': 579},
#  '36341': {'id': 36341,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000036341.jpg',
#   'height': 375},
#  '464474': {'id': 464474,
#   'set': 'train',
#   'width': 453,
#   'file_name': 'COCO_train2014_000000464474.jpg',
#   'height': 500},
#  '518389': {'id': 518389,
#   'set': 'train',
#   'width': 281,
#   'file_name': 'COCO_train2014_000000518389.jpg',
#   'height': 500},
#  '275775': {'id': 275775,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000275775.jpg',
#   'height': 427},
#  '175057': {'id': 175057,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000175057.jpg',
#   'height': 426},
#  '205707': {'id': 205707,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000205707.jpg',
#   'height': 427},
#  '22080': {'id': 22080,
#   'set': 'train',
#   'width': 503,
#   'file_name': 'COCO_train2014_000000022080.jpg',
#   'height': 640},
#  '456070': {'id': 456070,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000456070.jpg',
#   'height': 640},
#  '397986': {'id': 397986,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000397986.jpg',
#   'height': 427},
#  '289024': {'id': 289024,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000289024.jpg',
#   'height': 640},
#  '491029': {'id': 491029,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000491029.jpg',
#   'height': 480},
#  '183268': {'id': 183268,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000183268.jpg',
#   'height': 480},
#  '439678': {'id': 439678,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000439678.jpg',
#   'height': 425},
#  '375709': {'id': 375709,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000375709.jpg',
#   'height': 427},
#  '327032': {'id': 327032,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000327032.jpg',
#   'height': 480},
#  '551284': {'id': 551284,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000551284.jpg',
#   'height': 428},
#  '55536': {'id': 55536,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000055536.jpg',
#   'height': 504},
#  '88609': {'id': 88609,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000088609.jpg',
#   'height': 480},
#  '355389': {'id': 355389,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000355389.jpg',
#   'height': 375},
#  '96554': {'id': 96554,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000096554.jpg',
#   'height': 333},
#  '196090': {'id': 196090,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000196090.jpg',
#   'height': 375},
#  '172899': {'id': 172899,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000172899.jpg',
#   'height': 640},
#  '580277': {'id': 580277,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000580277.jpg',
#   'height': 427},
#  '243416': {'id': 243416,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000243416.jpg',
#   'height': 480},
#  '332316': {'id': 332316,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000332316.jpg',
#   'height': 480},
#  '19675': {'id': 19675,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000019675.jpg',
#   'height': 482},
#  '161019': {'id': 161019,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000161019.jpg',
#   'height': 640},
#  '376269': {'id': 376269,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000376269.jpg',
#   'height': 430},
#  '61895': {'id': 61895,
#   'set': 'val',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000061895.jpg',
#   'height': 375},
#  '412002': {'id': 412002,
#   'set': 'train',
#   'width': 512,
#   'file_name': 'COCO_train2014_000000412002.jpg',
#   'height': 640},
#  '496891': {'id': 496891,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000496891.jpg',
#   'height': 427},
#  '501441': {'id': 501441,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000501441.jpg',
#   'height': 480},
#  '559005': {'id': 559005,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000559005.jpg',
#   'height': 458},
#  '353206': {'id': 353206,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000353206.jpg',
#   'height': 480},
#  '493439': {'id': 493439,
#   'set': 'train',
#   'width': 479,
#   'file_name': 'COCO_train2014_000000493439.jpg',
#   'height': 640},
#  '308399': {'id': 308399,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000308399.jpg',
#   'height': 491},
#  '104395': {'id': 104395,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000104395.jpg',
#   'height': 640},
#  '86797': {'id': 86797,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000086797.jpg',
#   'height': 640},
#  '60600': {'id': 60600,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000060600.jpg',
#   'height': 426},
#  '178672': {'id': 178672,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000178672.jpg',
#   'height': 425},
#  '200778': {'id': 200778,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000200778.jpg',
#   'height': 480},
#  '280043': {'id': 280043,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000280043.jpg',
#   'height': 554},
#  '286645': {'id': 286645,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000286645.jpg',
#   'height': 480},
#  '261761': {'id': 261761,
#   'set': 'train',
#   'width': 612,
#   'file_name': 'COCO_train2014_000000261761.jpg',
#   'height': 612},
#  '197225': {'id': 197225,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000197225.jpg',
#   'height': 480},
#  '14798': {'id': 14798,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000014798.jpg',
#   'height': 427},
#  '431812': {'id': 431812,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000431812.jpg',
#   'height': 428},
#  '516889': {'id': 516889,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000516889.jpg',
#   'height': 476},
#  '159013': {'id': 159013,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000159013.jpg',
#   'height': 640},
#  '380482': {'id': 380482,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000380482.jpg',
#   'height': 413},
#  '290110': {'id': 290110,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000290110.jpg',
#   'height': 373},
#  '58619': {'id': 58619,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000058619.jpg',
#   'height': 480},
#  '85759': {'id': 85759,
#   'set': 'train',
#   'width': 426,
#   'file_name': 'COCO_train2014_000000085759.jpg',
#   'height': 640},
#  '289797': {'id': 289797,
#   'set': 'val',
#   'width': 478,
#   'file_name': 'COCO_train2014_000000289797.jpg',
#   'height': 640},
#  '44336': {'id': 44336,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000044336.jpg',
#   'height': 428},
#  '249538': {'id': 249538,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000249538.jpg',
#   'height': 333},
#  '222101': {'id': 222101,
#   'set': 'train',
#   'width': 333,
#   'file_name': 'COCO_train2014_000000222101.jpg',
#   'height': 500},
#  '492131': {'id': 492131,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000492131.jpg',
#   'height': 480},
#  '150541': {'id': 150541,
#   'set': 'train',
#   'width': 333,
#   'file_name': 'COCO_train2014_000000150541.jpg',
#   'height': 500},
#  '279935': {'id': 279935,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000279935.jpg',
#   'height': 480},
#  '561012': {'id': 561012,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000561012.jpg',
#   'height': 480},
#  '473723': {'id': 473723,
#   'set': 'val',
#   'width': 457,
#   'file_name': 'COCO_train2014_000000473723.jpg',
#   'height': 640},
#  '458772': {'id': 458772,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000458772.jpg',
#   'height': 358},
#  '358970': {'id': 358970,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000358970.jpg',
#   'height': 426},
#  '403888': {'id': 403888,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000403888.jpg',
#   'height': 424},
#  '200031': {'id': 200031,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000200031.jpg',
#   'height': 480},
#  '535308': {'id': 535308,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000535308.jpg',
#   'height': 393},
#  '298418': {'id': 298418,
#   'set': 'train',
#   'width': 479,
#   'file_name': 'COCO_train2014_000000298418.jpg',
#   'height': 640},
#  '407905': {'id': 407905,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000407905.jpg',
#   'height': 450},
#  '102669': {'id': 102669,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000102669.jpg',
#   'height': 427},
#  '439974': {'id': 439974,
#   'set': 'train',
#   'width': 457,
#   'file_name': 'COCO_train2014_000000439974.jpg',
#   'height': 640},
#  '369603': {'id': 369603,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000369603.jpg',
#   'height': 424},
#  '10614': {'id': 10614,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000010614.jpg',
#   'height': 639},
#  '71621': {'id': 71621,
#   'set': 'val',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000071621.jpg',
#   'height': 640},
#  '241305': {'id': 241305,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000241305.jpg',
#   'height': 419},
#  '241310': {'id': 241310,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000241310.jpg',
#   'height': 558},
#  '445464': {'id': 445464,
#   'set': 'train',
#   'width': 604,
#   'file_name': 'COCO_train2014_000000445464.jpg',
#   'height': 640},
#  '73244': {'id': 73244,
#   'set': 'train',
#   'width': 375,
#   'file_name': 'COCO_train2014_000000073244.jpg',
#   'height': 500},
#  '352247': {'id': 352247,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000352247.jpg',
#   'height': 480},
#  '211322': {'id': 211322,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000211322.jpg',
#   'height': 480},
#  '73837': {'id': 73837,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000073837.jpg',
#   'height': 427},
#  '230843': {'id': 230843,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000230843.jpg',
#   'height': 361},
#  '414178': {'id': 414178,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000414178.jpg',
#   'height': 461},
#  '69383': {'id': 69383,
#   'set': 'train',
#   'width': 612,
#   'file_name': 'COCO_train2014_000000069383.jpg',
#   'height': 612},
#  '338670': {'id': 338670,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000338670.jpg',
#   'height': 458},
#  '69733': {'id': 69733,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000069733.jpg',
#   'height': 426},
#  '268268': {'id': 268268,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000268268.jpg',
#   'height': 427},
#  '443003': {'id': 443003,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000443003.jpg',
#   'height': 480},
#  '460186': {'id': 460186,
#   'set': 'train',
#   'width': 425,
#   'file_name': 'COCO_train2014_000000460186.jpg',
#   'height': 640},
#  '469743': {'id': 469743,
#   'set': 'train',
#   'width': 426,
#   'file_name': 'COCO_train2014_000000469743.jpg',
#   'height': 640},
#  '116652': {'id': 116652,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000116652.jpg',
#   'height': 425},
#  '315795': {'id': 315795,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000315795.jpg',
#   'height': 519},
#  '181316': {'id': 181316,
#   'set': 'train',
#   'width': 426,
#   'file_name': 'COCO_train2014_000000181316.jpg',
#   'height': 640},
#  '265536': {'id': 265536,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000265536.jpg',
#   'height': 480},
#  '129715': {'id': 129715,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000129715.jpg',
#   'height': 480},
#  '90428': {'id': 90428,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000090428.jpg',
#   'height': 354},
#  '235987': {'id': 235987,
#   'set': 'train',
#   'width': 471,
#   'file_name': 'COCO_train2014_000000235987.jpg',
#   'height': 640},
#  '420045': {'id': 420045,
#   'set': 'val',
#   'width': 478,
#   'file_name': 'COCO_train2014_000000420045.jpg',
#   'height': 640},
#  '277129': {'id': 277129,
#   'set': 'train',
#   'width': 450,
#   'file_name': 'COCO_train2014_000000277129.jpg',
#   'height': 300},
#  '58597': {'id': 58597,
#   'set': 'train',
#   'width': 469,
#   'file_name': 'COCO_train2014_000000058597.jpg',
#   'height': 640},
#  '256576': {'id': 256576,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000256576.jpg',
#   'height': 375},
#  '165803': {'id': 165803,
#   'set': 'val',
#   'width': 427,
#   'file_name': 'COCO_train2014_000000165803.jpg',
#   'height': 640},
#  '365614': {'id': 365614,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000365614.jpg',
#   'height': 640},
#  '162996': {'id': 162996,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000162996.jpg',
#   'height': 480},
#  '124182': {'id': 124182,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000124182.jpg',
#   'height': 480},
#  '194579': {'id': 194579,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000194579.jpg',
#   'height': 427},
#  '32275': {'id': 32275,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000032275.jpg',
#   'height': 480},
#  '556476': {'id': 556476,
#   'set': 'train',
#   'width': 426,
#   'file_name': 'COCO_train2014_000000556476.jpg',
#   'height': 640},
#  '333687': {'id': 333687,
#   'set': 'val',
#   'width': 512,
#   'file_name': 'COCO_train2014_000000333687.jpg',
#   'height': 640},
#  '536939': {'id': 536939,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000536939.jpg',
#   'height': 640},
#  '549404': {'id': 549404,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000549404.jpg',
#   'height': 439},
#  '262704': {'id': 262704,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000262704.jpg',
#   'height': 479},
#  '437902': {'id': 437902,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000437902.jpg',
#   'height': 465},
#  '208535': {'id': 208535,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000208535.jpg',
#   'height': 428},
#  '28974': {'id': 28974,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000028974.jpg',
#   'height': 457},
#  '208274': {'id': 208274,
#   'set': 'train',
#   'width': 427,
#   'file_name': 'COCO_train2014_000000208274.jpg',
#   'height': 640},
#  '35663': {'id': 35663,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000035663.jpg',
#   'height': 333},
#  '469888': {'id': 469888,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000469888.jpg',
#   'height': 428},
#  '570522': {'id': 570522,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000570522.jpg',
#   'height': 375},
#  '157636': {'id': 157636,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000157636.jpg',
#   'height': 636},
#  '558555': {'id': 558555,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000558555.jpg',
#   'height': 426},
#  '497698': {'id': 497698,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000497698.jpg',
#   'height': 416},
#  '461494': {'id': 461494,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000461494.jpg',
#   'height': 480},
#  '385085': {'id': 385085,
#   'set': 'val',
#   'width': 426,
#   'file_name': 'COCO_train2014_000000385085.jpg',
#   'height': 640},
#  '106329': {'id': 106329,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000106329.jpg',
#   'height': 427},
#  '182406': {'id': 182406,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000182406.jpg',
#   'height': 480},
#  '295565': {'id': 295565,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000295565.jpg',
#   'height': 428},
#  '391388': {'id': 391388,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000391388.jpg',
#   'height': 480},
#  '91697': {'id': 91697,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000091697.jpg',
#   'height': 427},
#  '113334': {'id': 113334,
#   'set': 'train',
#   'width': 333,
#   'file_name': 'COCO_train2014_000000113334.jpg',
#   'height': 500},
#  '434234': {'id': 434234,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000434234.jpg',
#   'height': 480},
#  '378929': {'id': 378929,
#   'set': 'train',
#   'width': 333,
#   'file_name': 'COCO_train2014_000000378929.jpg',
#   'height': 640},
#  '14818': {'id': 14818,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000014818.jpg',
#   'height': 480},
#  '541314': {'id': 541314,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000541314.jpg',
#   'height': 360},
#  '203994': {'id': 203994,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000203994.jpg',
#   'height': 425},
#  '9057': {'id': 9057,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000009057.jpg',
#   'height': 480},
#  '226136': {'id': 226136,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000226136.jpg',
#   'height': 360},
#  '178789': {'id': 178789,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000178789.jpg',
#   'height': 427},
#  '194725': {'id': 194725,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000194725.jpg',
#   'height': 480},
#  '276209': {'id': 276209,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000276209.jpg',
#   'height': 640},
#  '105697': {'id': 105697,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000105697.jpg',
#   'height': 427},
#  '280926': {'id': 280926,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000280926.jpg',
#   'height': 579},
#  '235409': {'id': 235409,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000235409.jpg',
#   'height': 640},
#  '239933': {'id': 239933,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000239933.jpg',
#   'height': 427},
#  '5362': {'id': 5362,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000005362.jpg',
#   'height': 333},
#  '48947': {'id': 48947,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000048947.jpg',
#   'height': 426},
#  '513618': {'id': 513618,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000513618.jpg',
#   'height': 335},
#  '374185': {'id': 374185,
#   'set': 'train',
#   'width': 479,
#   'file_name': 'COCO_train2014_000000374185.jpg',
#   'height': 640},
#  '485387': {'id': 485387,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000485387.jpg',
#   'height': 480},
#  '408182': {'id': 408182,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000408182.jpg',
#   'height': 422},
#  '66487': {'id': 66487,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000066487.jpg',
#   'height': 360},
#  '194540': {'id': 194540,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000194540.jpg',
#   'height': 480},
#  '74183': {'id': 74183,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000074183.jpg',
#   'height': 489},
#  '153601': {'id': 153601,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000153601.jpg',
#   'height': 427},
#  '517699': {'id': 517699,
#   'set': 'train',
#   'width': 612,
#   'file_name': 'COCO_train2014_000000517699.jpg',
#   'height': 612},
#  '12933': {'id': 12933,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000012933.jpg',
#   'height': 375},
#  '192009': {'id': 192009,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000192009.jpg',
#   'height': 427},
#  '403999': {'id': 403999,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000403999.jpg',
#   'height': 480},
#  '268441': {'id': 268441,
#   'set': 'train',
#   'width': 439,
#   'file_name': 'COCO_train2014_000000268441.jpg',
#   'height': 640},
#  '31288': {'id': 31288,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000031288.jpg',
#   'height': 640},
#  '32606': {'id': 32606,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000032606.jpg',
#   'height': 480},
#  '488833': {'id': 488833,
#   'set': 'val',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000488833.jpg',
#   'height': 640},
#  '235812': {'id': 235812,
#   'set': 'train',
#   'width': 427,
#   'file_name': 'COCO_train2014_000000235812.jpg',
#   'height': 640},
#  '203459': {'id': 203459,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000203459.jpg',
#   'height': 480},
#  '145163': {'id': 145163,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000145163.jpg',
#   'height': 375},
#  '342618': {'id': 342618,
#   'set': 'train',
#   'width': 612,
#   'file_name': 'COCO_train2014_000000342618.jpg',
#   'height': 612},
#  '411501': {'id': 411501,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000411501.jpg',
#   'height': 478},
#  '348968': {'id': 348968,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000348968.jpg',
#   'height': 480},
#  '442326': {'id': 442326,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000442326.jpg',
#   'height': 360},
#  '505903': {'id': 505903,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000505903.jpg',
#   'height': 483},
#  '312344': {'id': 312344,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000312344.jpg',
#   'height': 480},
#  '72550': {'id': 72550,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000072550.jpg',
#   'height': 473},
#  '357684': {'id': 357684,
#   'set': 'train',
#   'width': 496,
#   'file_name': 'COCO_train2014_000000357684.jpg',
#   'height': 640},
#  '384740': {'id': 384740,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000384740.jpg',
#   'height': 480},
#  '9656': {'id': 9656,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000009656.jpg',
#   'height': 480},
#  '509267': {'id': 509267,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000509267.jpg',
#   'height': 441},
#  '388469': {'id': 388469,
#   'set': 'val',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000388469.jpg',
#   'height': 210},
#  '157656': {'id': 157656,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000157656.jpg',
#   'height': 480},
#  '243127': {'id': 243127,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000243127.jpg',
#   'height': 481},
#  '444024': {'id': 444024,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000444024.jpg',
#   'height': 480},
#  '105877': {'id': 105877,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000105877.jpg',
#   'height': 480},
#  '197570': {'id': 197570,
#   'set': 'val',
#   'width': 332,
#   'file_name': 'COCO_train2014_000000197570.jpg',
#   'height': 500},
#  '190177': {'id': 190177,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000190177.jpg',
#   'height': 375},
#  '318365': {'id': 318365,
#   'set': 'train',
#   'width': 427,
#   'file_name': 'COCO_train2014_000000318365.jpg',
#   'height': 640},
#  '14307': {'id': 14307,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000014307.jpg',
#   'height': 427},
#  '8564': {'id': 8564,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000008564.jpg',
#   'height': 427},
#  '201969': {'id': 201969,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000201969.jpg',
#   'height': 480},
#  '366414': {'id': 366414,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000366414.jpg',
#   'height': 480},
#  '122834': {'id': 122834,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000122834.jpg',
#   'height': 480},
#  '105987': {'id': 105987,
#   'set': 'train',
#   'width': 427,
#   'file_name': 'COCO_train2014_000000105987.jpg',
#   'height': 640},
#  '440827': {'id': 440827,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000440827.jpg',
#   'height': 426},
#  '35712': {'id': 35712,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000035712.jpg',
#   'height': 480},
#  '400571': {'id': 400571,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000400571.jpg',
#   'height': 426},
#  '382517': {'id': 382517,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000382517.jpg',
#   'height': 640},
#  '543797': {'id': 543797,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000543797.jpg',
#   'height': 425},
#  '345263': {'id': 345263,
#   'set': 'val',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000345263.jpg',
#   'height': 286},
#  '429741': {'id': 429741,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000429741.jpg',
#   'height': 480},
#  '472157': {'id': 472157,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000472157.jpg',
#   'height': 427},
#  '60433': {'id': 60433,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000060433.jpg',
#   'height': 462},
#  '535137': {'id': 535137,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000535137.jpg',
#   'height': 375},
#  '391297': {'id': 391297,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000391297.jpg',
#   'height': 427},
#  '262180': {'id': 262180,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000262180.jpg',
#   'height': 480},
#  '162161': {'id': 162161,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000162161.jpg',
#   'height': 523},
#  '196663': {'id': 196663,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000196663.jpg',
#   'height': 480},
#  '212963': {'id': 212963,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000212963.jpg',
#   'height': 618},
#  '11168': {'id': 11168,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000011168.jpg',
#   'height': 426},
#  '111598': {'id': 111598,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000111598.jpg',
#   'height': 428},
#  '274977': {'id': 274977,
#   'set': 'train',
#   'width': 427,
#   'file_name': 'COCO_train2014_000000274977.jpg',
#   'height': 640},
#  '426880': {'id': 426880,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000426880.jpg',
#   'height': 429},
#  '124532': {'id': 124532,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000124532.jpg',
#   'height': 426},
#  '16448': {'id': 16448,
#   'set': 'val',
#   'width': 375,
#   'file_name': 'COCO_train2014_000000016448.jpg',
#   'height': 500},
#  '145690': {'id': 145690,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000145690.jpg',
#   'height': 480},
#  '374375': {'id': 374375,
#   'set': 'train',
#   'width': 612,
#   'file_name': 'COCO_train2014_000000374375.jpg',
#   'height': 612},
#  '468321': {'id': 468321,
#   'set': 'train',
#   'width': 427,
#   'file_name': 'COCO_train2014_000000468321.jpg',
#   'height': 640},
#  '263878': {'id': 263878,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000263878.jpg',
#   'height': 480},
#  '366162': {'id': 366162,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000366162.jpg',
#   'height': 422},
#  '159704': {'id': 159704,
#   'set': 'train',
#   'width': 427,
#   'file_name': 'COCO_train2014_000000159704.jpg',
#   'height': 500},
#  '509607': {'id': 509607,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000509607.jpg',
#   'height': 568},
#  '193954': {'id': 193954,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000193954.jpg',
#   'height': 640},
#  '196842': {'id': 196842,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000196842.jpg',
#   'height': 333},
#  '487090': {'id': 487090,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000487090.jpg',
#   'height': 426},
#  '558036': {'id': 558036,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000558036.jpg',
#   'height': 508},
#  '271949': {'id': 271949,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000271949.jpg',
#   'height': 429},
#  '547131': {'id': 547131,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000547131.jpg',
#   'height': 480},
#  '250566': {'id': 250566,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000250566.jpg',
#   'height': 425},
#  '162524': {'id': 162524,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000162524.jpg',
#   'height': 426},
#  '150838': {'id': 150838,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000150838.jpg',
#   'height': 426},
#  '224878': {'id': 224878,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000224878.jpg',
#   'height': 426},
#  '342135': {'id': 342135,
#   'set': 'train',
#   'width': 424,
#   'file_name': 'COCO_train2014_000000342135.jpg',
#   'height': 640},
#  '153879': {'id': 153879,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000153879.jpg',
#   'height': 480},
#  '417844': {'id': 417844,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000417844.jpg',
#   'height': 495},
#  '403520': {'id': 403520,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000403520.jpg',
#   'height': 480},
#  '20475': {'id': 20475,
#   'set': 'train',
#   'width': 427,
#   'file_name': 'COCO_train2014_000000020475.jpg',
#   'height': 640},
#  '475735': {'id': 475735,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000475735.jpg',
#   'height': 427},
#  '3917': {'id': 3917,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000003917.jpg',
#   'height': 480},
#  '473090': {'id': 473090,
#   'set': 'train',
#   'width': 426,
#   'file_name': 'COCO_train2014_000000473090.jpg',
#   'height': 640},
#  '271568': {'id': 271568,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000271568.jpg',
#   'height': 480},
#  '98892': {'id': 98892,
#   'set': 'train',
#   'width': 333,
#   'file_name': 'COCO_train2014_000000098892.jpg',
#   'height': 500},
#  '577246': {'id': 577246,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000577246.jpg',
#   'height': 513},
#  '550235': {'id': 550235,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000550235.jpg',
#   'height': 375},
#  '96973': {'id': 96973,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000096973.jpg',
#   'height': 427},
#  '165271': {'id': 165271,
#   'set': 'val',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000165271.jpg',
#   'height': 640},
#  '86169': {'id': 86169,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000086169.jpg',
#   'height': 480},
#  '200782': {'id': 200782,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000200782.jpg',
#   'height': 480},
#  '363455': {'id': 363455,
#   'set': 'val',
#   'width': 478,
#   'file_name': 'COCO_train2014_000000363455.jpg',
#   'height': 640},
#  '262705': {'id': 262705,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000262705.jpg',
#   'height': 480},
#  '131572': {'id': 131572,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000131572.jpg',
#   'height': 480},
#  '122159': {'id': 122159,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000122159.jpg',
#   'height': 480},
#  '68700': {'id': 68700,
#   'set': 'train',
#   'width': 595,
#   'file_name': 'COCO_train2014_000000068700.jpg',
#   'height': 640},
#  '500603': {'id': 500603,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000500603.jpg',
#   'height': 509},
#  '143490': {'id': 143490,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000143490.jpg',
#   'height': 426},
#  '196290': {'id': 196290,
#   'set': 'val',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000196290.jpg',
#   'height': 333},
#  '178436': {'id': 178436,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000178436.jpg',
#   'height': 428},
#  '163478': {'id': 163478,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000163478.jpg',
#   'height': 400},
#  '81031': {'id': 81031,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000081031.jpg',
#   'height': 427},
#  '136396': {'id': 136396,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000136396.jpg',
#   'height': 480},
#  '323056': {'id': 323056,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000323056.jpg',
#   'height': 375},
#  '257391': {'id': 257391,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000257391.jpg',
#   'height': 640},
#  '173163': {'id': 173163,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000173163.jpg',
#   'height': 427},
#  '540370': {'id': 540370,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000540370.jpg',
#   'height': 480},
#  '496097': {'id': 496097,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000496097.jpg',
#   'height': 425},
#  '23140': {'id': 23140,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000023140.jpg',
#   'height': 427},
#  '176098': {'id': 176098,
#   'set': 'train',
#   'width': 427,
#   'file_name': 'COCO_train2014_000000176098.jpg',
#   'height': 640},
#  '367187': {'id': 367187,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000367187.jpg',
#   'height': 398},
#  '97530': {'id': 97530,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000097530.jpg',
#   'height': 640},
#  '274079': {'id': 274079,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000274079.jpg',
#   'height': 480},
#  '233609': {'id': 233609,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000233609.jpg',
#   'height': 426},
#  '466924': {'id': 466924,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000466924.jpg',
#   'height': 421},
#  '308589': {'id': 308589,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000308589.jpg',
#   'height': 414},
#  '60458': {'id': 60458,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000060458.jpg',
#   'height': 480},
#  '120462': {'id': 120462,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000120462.jpg',
#   'height': 427},
#  '232344': {'id': 232344,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000232344.jpg',
#   'height': 640},
#  '334596': {'id': 334596,
#   'set': 'train',
# ...
#   'width': 640,
#   'file_name': 'COCO_train2014_000000306044.jpg',
#   'height': 427},
#  '279616': {'id': 279616,
#   'set': 'train',
#   'width': 600,
#   'file_name': 'COCO_train2014_000000279616.jpg',
#   'height': 409},
#  '97895': {'id': 97895,
#   'set': 'train',
#   'width': 482,
#   'file_name': 'COCO_train2014_000000097895.jpg',
#   'height': 484},
#  '42312': {'id': 42312,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000042312.jpg',
#   'height': 515},
#  '77563': {'id': 77563,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000077563.jpg',
#   'height': 480},
#  '48892': {'id': 48892,
#   'set': 'val',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000048892.jpg',
#   'height': 640},
#  '296614': {'id': 296614,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000296614.jpg',
#   'height': 427},
#  '482766': {'id': 482766,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000482766.jpg',
#   'height': 640},
#  '212873': {'id': 212873,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000212873.jpg',
#   'height': 480},
#  '345655': {'id': 345655,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000345655.jpg',
#   'height': 640},
#  '139389': {'id': 139389,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000139389.jpg',
#   'height': 480},
#  '555308': {'id': 555308,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000555308.jpg',
#   'height': 360},
#  '322692': {'id': 322692,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000322692.jpg',
#   'height': 428},
#  '233575': {'id': 233575,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000233575.jpg',
#   'height': 426},
#  '43110': {'id': 43110,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000043110.jpg',
#   'height': 427},
#  '466042': {'id': 466042,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000466042.jpg',
#   'height': 480},
#  '159714': {'id': 159714,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000159714.jpg',
#   'height': 458},
#  '402384': {'id': 402384,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000402384.jpg',
#   'height': 480},
#  '129262': {'id': 129262,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000129262.jpg',
#   'height': 640},
#  '203940': {'id': 203940,
#   'set': 'val',
#   'width': 333,
#   'file_name': 'COCO_train2014_000000203940.jpg',
#   'height': 500},
#  '180606': {'id': 180606,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000180606.jpg',
#   'height': 426},
#  '226539': {'id': 226539,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000226539.jpg',
#   'height': 640},
#  '570543': {'id': 570543,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000570543.jpg',
#   'height': 480},
#  '381221': {'id': 381221,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000381221.jpg',
#   'height': 492},
#  '495310': {'id': 495310,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000495310.jpg',
#   'height': 427},
#  '356061': {'id': 356061,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000356061.jpg',
#   'height': 427},
#  '205668': {'id': 205668,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000205668.jpg',
#   'height': 427},
#  '376279': {'id': 376279,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000376279.jpg',
#   'height': 375},
#  '33751': {'id': 33751,
#   'set': 'val',
#   'width': 478,
#   'file_name': 'COCO_train2014_000000033751.jpg',
#   'height': 640},
#  '73726': {'id': 73726,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000073726.jpg',
#   'height': 480},
#  '101283': {'id': 101283,
#   'set': 'train',
#   'width': 429,
#   'file_name': 'COCO_train2014_000000101283.jpg',
#   'height': 640},
#  '314167': {'id': 314167,
#   'set': 'train',
#   'width': 375,
#   'file_name': 'COCO_train2014_000000314167.jpg',
#   'height': 500},
#  '483769': {'id': 483769,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000483769.jpg',
#   'height': 341},
#  '541591': {'id': 541591,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000541591.jpg',
#   'height': 480},
#  '404351': {'id': 404351,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000404351.jpg',
#   'height': 426},
#  '206486': {'id': 206486,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000206486.jpg',
#   'height': 624},
#  '26932': {'id': 26932,
#   'set': 'train',
#   'width': 512,
#   'file_name': 'COCO_train2014_000000026932.jpg',
#   'height': 640},
#  '37880': {'id': 37880,
#   'set': 'train',
#   'width': 290,
#   'file_name': 'COCO_train2014_000000037880.jpg',
#   'height': 438},
#  '518501': {'id': 518501,
#   'set': 'train',
#   'width': 483,
#   'file_name': 'COCO_train2014_000000518501.jpg',
#   'height': 640},
#  '300772': {'id': 300772,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000300772.jpg',
#   'height': 640},
#  '284732': {'id': 284732,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000284732.jpg',
#   'height': 427},
#  '337062': {'id': 337062,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000337062.jpg',
#   'height': 640},
#  '32967': {'id': 32967,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000032967.jpg',
#   'height': 426},
#  '4319': {'id': 4319,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000004319.jpg',
#   'height': 427},
#  '241288': {'id': 241288,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000241288.jpg',
#   'height': 427},
#  '28281': {'id': 28281,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000028281.jpg',
#   'height': 640},
#  '505701': {'id': 505701,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000505701.jpg',
#   'height': 427},
#  '360045': {'id': 360045,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000360045.jpg',
#   'height': 483},
#  '111812': {'id': 111812,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000111812.jpg',
#   'height': 640},
#  '238688': {'id': 238688,
#   'set': 'train',
#   'width': 428,
#   'file_name': 'COCO_train2014_000000238688.jpg',
#   'height': 640},
#  '157160': {'id': 157160,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000157160.jpg',
#   'height': 427},
#  '255258': {'id': 255258,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000255258.jpg',
#   'height': 360},
#  '61217': {'id': 61217,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000061217.jpg',
#   'height': 427},
#  '381694': {'id': 381694,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000381694.jpg',
#   'height': 359},
#  '264085': {'id': 264085,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000264085.jpg',
#   'height': 640},
#  '508836': {'id': 508836,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000508836.jpg',
#   'height': 424},
#  '483955': {'id': 483955,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000483955.jpg',
#   'height': 640},
#  '566899': {'id': 566899,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000566899.jpg',
#   'height': 480},
#  '155862': {'id': 155862,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000155862.jpg',
#   'height': 362},
#  '34795': {'id': 34795,
#   'set': 'train',
#   'width': 375,
#   'file_name': 'COCO_train2014_000000034795.jpg',
#   'height': 500},
#  '561346': {'id': 561346,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000561346.jpg',
#   'height': 640},
#  '78354': {'id': 78354,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000078354.jpg',
#   'height': 414},
#  '105863': {'id': 105863,
#   'set': 'val',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000105863.jpg',
#   'height': 640},
#  '247459': {'id': 247459,
#   'set': 'train',
#   'width': 428,
#   'file_name': 'COCO_train2014_000000247459.jpg',
#   'height': 640},
#  '164287': {'id': 164287,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000164287.jpg',
#   'height': 426},
#  '464736': {'id': 464736,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000464736.jpg',
#   'height': 640},
#  '55484': {'id': 55484,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000055484.jpg',
#   'height': 427},
#  '166556': {'id': 166556,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000166556.jpg',
#   'height': 326},
#  '291320': {'id': 291320,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000291320.jpg',
#   'height': 426},
#  '183336': {'id': 183336,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000183336.jpg',
#   'height': 383},
#  '193359': {'id': 193359,
#   'set': 'train',
#   'width': 427,
#   'file_name': 'COCO_train2014_000000193359.jpg',
#   'height': 640},
#  '520259': {'id': 520259,
#   'set': 'train',
#   'width': 428,
#   'file_name': 'COCO_train2014_000000520259.jpg',
#   'height': 640},
#  '273886': {'id': 273886,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000273886.jpg',
#   'height': 480},
#  '534065': {'id': 534065,
#   'set': 'val',
#   'width': 426,
#   'file_name': 'COCO_train2014_000000534065.jpg',
#   'height': 640},
#  '115637': {'id': 115637,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000115637.jpg',
#   'height': 443},
#  '50868': {'id': 50868,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000050868.jpg',
#   'height': 561},
#  '319440': {'id': 319440,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000319440.jpg',
#   'height': 427},
#  '531568': {'id': 531568,
#   'set': 'train',
#   'width': 457,
#   'file_name': 'COCO_train2014_000000531568.jpg',
#   'height': 640},
#  '338864': {'id': 338864,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000338864.jpg',
#   'height': 480},
#  '76103': {'id': 76103,
#   'set': 'train',
#   'width': 600,
#   'file_name': 'COCO_train2014_000000076103.jpg',
#   'height': 400},
#  '216042': {'id': 216042,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000216042.jpg',
#   'height': 480},
#  '521709': {'id': 521709,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000521709.jpg',
#   'height': 480},
#  '559645': {'id': 559645,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000559645.jpg',
#   'height': 375},
#  '97218': {'id': 97218,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000097218.jpg',
#   'height': 480},
#  '196307': {'id': 196307,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000196307.jpg',
#   'height': 640},
#  '7201': {'id': 7201,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000007201.jpg',
#   'height': 427},
#  '56605': {'id': 56605,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000056605.jpg',
#   'height': 480},
#  '126755': {'id': 126755,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000126755.jpg',
#   'height': 425},
#  '353634': {'id': 353634,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000353634.jpg',
#   'height': 286},
#  '99321': {'id': 99321,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000099321.jpg',
#   'height': 425},
#  '91023': {'id': 91023,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000091023.jpg',
#   'height': 427},
#  '258642': {'id': 258642,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000258642.jpg',
#   'height': 480},
#  '310348': {'id': 310348,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000310348.jpg',
#   'height': 427},
#  '63782': {'id': 63782,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000063782.jpg',
#   'height': 427},
#  '337353': {'id': 337353,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000337353.jpg',
#   'height': 426},
#  '289107': {'id': 289107,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000289107.jpg',
#   'height': 480},
#  '137096': {'id': 137096,
#   'set': 'train',
#   'width': 376,
#   'file_name': 'COCO_train2014_000000137096.jpg',
#   'height': 500},
#  '392067': {'id': 392067,
#   'set': 'val',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000392067.jpg',
#   'height': 375},
#  '306552': {'id': 306552,
#   'set': 'train',
#   'width': 333,
#   'file_name': 'COCO_train2014_000000306552.jpg',
#   'height': 500},
#  '508710': {'id': 508710,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000508710.jpg',
#   'height': 553},
#  '277163': {'id': 277163,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000277163.jpg',
#   'height': 428},
#  '47640': {'id': 47640,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000047640.jpg',
#   'height': 427},
#  '522492': {'id': 522492,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000522492.jpg',
#   'height': 480},
#  '286382': {'id': 286382,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000286382.jpg',
#   'height': 480},
#  '320926': {'id': 320926,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000320926.jpg',
#   'height': 480},
#  '506066': {'id': 506066,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000506066.jpg',
#   'height': 640},
#  '208020': {'id': 208020,
#   'set': 'train',
#   'width': 326,
#   'file_name': 'COCO_train2014_000000208020.jpg',
#   'height': 500},
#  '84603': {'id': 84603,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000084603.jpg',
#   'height': 640},
#  '551185': {'id': 551185,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000551185.jpg',
#   'height': 488},
#  '393268': {'id': 393268,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000393268.jpg',
#   'height': 480},
#  '135539': {'id': 135539,
#   'set': 'val',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000135539.jpg',
#   'height': 480},
#  '461042': {'id': 461042,
#   'set': 'train',
#   'width': 500,
#   'file_name': 'COCO_train2014_000000461042.jpg',
#   'height': 375},
#  '463019': {'id': 463019,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000463019.jpg',
#   'height': 425},
#  '135775': {'id': 135775,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000135775.jpg',
#   'height': 480},
#  '208910': {'id': 208910,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000208910.jpg',
#   'height': 640},
#  '540750': {'id': 540750,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000540750.jpg',
#   'height': 480},
#  '38310': {'id': 38310,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000038310.jpg',
#   'height': 448},
#  '228398': {'id': 228398,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000228398.jpg',
#   'height': 480},
#  '350360': {'id': 350360,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000350360.jpg',
#   'height': 474},
#  '60720': {'id': 60720,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000060720.jpg',
#   'height': 480},
#  '346309': {'id': 346309,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000346309.jpg',
#   'height': 640},
#  '341060': {'id': 341060,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000341060.jpg',
#   'height': 426},
#  '462577': {'id': 462577,
#   'set': 'train',
#   'width': 427,
#   'file_name': 'COCO_train2014_000000462577.jpg',
#   'height': 640},
#  '239461': {'id': 239461,
#   'set': 'train',
#   'width': 480,
#   'file_name': 'COCO_train2014_000000239461.jpg',
#   'height': 640},
#  '319451': {'id': 319451,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000319451.jpg',
#   'height': 429},
#  '520208': {'id': 520208,
#   'set': 'train',
#   'width': 640,
#   'file_name': 'COCO_train2014_000000520208.jpg',
#   'height': 480},
#  ...}

# %%
list(data['anns'].values())[0]
# Out:
# {'mask': [468.9, 286.7, 468.9, 295.2, 493.0, 295.8, 493.0, 287.2],
#  'class': 'machine printed',
#  'bbox': [468.9, 286.7, 24.1, 9.1],
#  'image_id': 217925,
#  'id': 45346,
#  'language': 'english',
#  'area': 206.06,
#  'utf8_string': 'New',
#  'legibility': 'legible'}

# %%
class CocoLikeDataset(utils.Dataset):
    """ Generates a COCO-like dataset, i.e. an image dataset annotated in the style of the COCO dataset.
        See http://cocodataset.org/#home for more information.
    """
    def load_data(self, annotation_json, images_dir):
        """ Load the coco-like dataset from json
        Args:
            annotation_json: The path to the coco annotations json file
            images_dir: The directory holding the images referred to by the json file
        """
        # Load json from file
        json_file = open(annotation_json)
        coco_json = json.load(json_file)
        json_file.close()
        
        # Add the class names using the base method from utils.Dataset
        source_name = "coco_like"
        class_id = 1
        class_name = 'text'
        self.add_class(source_name, class_id, class_name)
        
        
        # Get all annotations
        annotations = {}
        for annotation in coco_json['anns'].values():
            image_id = annotation['image_id']
            if image_id not in annotations:
                annotations[image_id] = []
            annotations[image_id].append(annotation)
        
        # Get all images and add them to the dataset
        seen_images = {}
        for image in coco_json['imgs'].values():
            
            image_id = image['id']
            if image_id in seen_images:
                print("Warning: Skipping duplicate image id: {}".format(image))
            else:
                seen_images[image_id] = image
                try:
                    image_file_name = image['file_name']
                    image_width = image['width']
                    image_height = image['height']
                except KeyError as key:
                    print("Warning: Skipping image (id: {}) with missing key: {}".format(image_id, key))
                
                image_path = os.path.abspath(os.path.join(images_dir, image_file_name))
                #self.anns = annotations
                if image_id in annotations.keys() and os.path.isfile(image_path): 
                    image_annotations = annotations[image_id]

                    # Add the image using the base method from utils.Dataset

                    self.add_image(
                        source=source_name,
                        image_id=image_id,
                        path=image_path,
                        width=image_width,
                        height=image_height,
                        annotations=image_annotations
                    )
                
    def load_mask(self, image_id):
        """ Load instance masks for the given image.
        MaskRCNN expects masks in the form of a bitmap [height, width, instances].
        Args:
            image_id: The id of the image to load masks for
        Returns:
            masks: A bool array of shape [height, width, instance count] with
                one mask per instance.
            class_ids: a 1D array of class IDs of the instance masks.
        """
        image_info = self.image_info[image_id]
        annotations = image_info['annotations']
        instance_masks = []
        #class_ids = []
        
        for annotation in annotations:
            #class_id = annotation['category_id']
            mask = Image.new('1', (image_info['width'], image_info['height']))
            mask_draw = ImageDraw.ImageDraw(mask, '1')
            if isinstance(annotation['mask'], list):
                mask_draw.polygon(annotation['mask'], fill=1)
                bool_array = np.array(mask) > 0
                instance_masks.append(bool_array)
                #print('ffff')
            else:
                for segmentation in annotation['mask']:
                    print(type(segmentation))
                    mask_draw.polygon(segmentation, fill=1)
                    bool_array = np.array(mask) > 0
                    instance_masks.append(bool_array)
                    #class_ids.append(class_id)

        mask = np.dstack(instance_masks)
        #class_ids = np.array(class_ids, dtype=np.int32)
        
        return mask, np.ones([mask.shape[-1]], dtype=np.int32)

# %% [markdown]
# # Create the Training and Validation Datasets
# Make sure you download the training dataset linked at the top of this notebook. If you put the dataset somewhere else, update the paths below.

# %%
dataset_train = CocoLikeDataset()
dataset_train.load_data('cocotext.v2.json', 'train2014')
dataset_train.prepare()

dataset_val = CocoLikeDataset()
dataset_val.load_data('cocotext.v2.json', 'val')
dataset_val.prepare()

# %% [markdown]
# ## Display a few images from the training dataset

# %%
dataset = dataset_val
image_ids = np.random.choice(dataset.image_ids, 4)
for image_id in image_ids:
    image = dataset.load_image(image_id)
    mask, class_ids = dataset.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset.class_names)

# %% [markdown]
# # Create the Training Model and Train
# This code is largely borrowed from the train_shapes.ipynb notebook.

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)

# %%
# Which weights to start with?
init_with = "last"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last(), by_name=True)
# Out:
# Re-starting from epoch 50

# %% [markdown]
# ## Training
#
# Train in two stages:
#
# 1. Only the heads. Here we're freezing all the backbone layers and training only the randomly initialized layers (i.e. the ones that we didn't use pre-trained weights from MS COCO). To train only the head layers, pass layers='heads' to the train() function.
#
# 2. Fine-tune all layers. For this simple example it's not necessary, but we're including it to show the process. Simply pass layers="all to train all layers.

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
start_train = time.time()
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=50, 
            layers='heads')
end_train = time.time()
minutes = round((end_train - start_train) / 60, 2)
print(f'Training took {minutes} minutes')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: logs/coco_text20190313T2147/mask_rcnn_coco_text_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# /home/cruigo/.local/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /home/cruigo/anaconda3/lib/python3.6/site-packages/keras/engine/training_generator.py:47: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Epoch 1/50
# 500/500 [==============================] - 2268s 5s/step - loss: 2.2710 - rpn_class_loss: 0.1095 - rpn_bbox_loss: 0.9818 - mrcnn_class_loss: 0.1391 - mrcnn_bbox_loss: 0.5909 - mrcnn_mask_loss: 0.4496 - val_loss: 3.3404 - val_rpn_class_loss: 0.1186 - val_rpn_bbox_loss: 1.3938 - val_mrcnn_class_loss: 0.3140 - val_mrcnn_bbox_loss: 0.9894 - val_mrcnn_mask_loss: 0.5246
# Epoch 2/50
# 500/500 [==============================] - 2245s 4s/step - loss: 2.1951 - rpn_class_loss: 0.0875 - rpn_bbox_loss: 0.9182 - mrcnn_class_loss: 0.1905 - mrcnn_bbox_loss: 0.5399 - mrcnn_mask_loss: 0.4591 - val_loss: 2.4362 - val_rpn_class_loss: 0.0734 - val_rpn_bbox_loss: 1.3636 - val_mrcnn_class_loss: 0.0681 - val_mrcnn_bbox_loss: 0.5760 - val_mrcnn_mask_loss: 0.3551
# Epoch 3/50
# 500/500 [==============================] - 2246s 4s/step - loss: 2.1736 - rpn_class_loss: 0.0920 - rpn_bbox_loss: 0.9943 - mrcnn_class_loss: 0.1547 - mrcnn_bbox_loss: 0.5112 - mrcnn_mask_loss: 0.4214 - val_loss: 1.6912 - val_rpn_class_loss: 0.1016 - val_rpn_bbox_loss: 1.5896 - val_mrcnn_class_loss: 2.3603e-05 - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 4/50
# 500/500 [==============================] - 2249s 4s/step - loss: 2.2652 - rpn_class_loss: 0.0801 - rpn_bbox_loss: 1.0210 - mrcnn_class_loss: 0.2019 - mrcnn_bbox_loss: 0.5142 - mrcnn_mask_loss: 0.4480 - val_loss: 3.2699 - val_rpn_class_loss: 0.3438 - val_rpn_bbox_loss: 1.6200 - val_mrcnn_class_loss: 0.3357 - val_mrcnn_bbox_loss: 0.5567 - val_mrcnn_mask_loss: 0.4137
# Epoch 5/50
# 500/500 [==============================] - 2256s 5s/step - loss: 2.1731 - rpn_class_loss: 0.0778 - rpn_bbox_loss: 0.9286 - mrcnn_class_loss: 0.2356 - mrcnn_bbox_loss: 0.4895 - mrcnn_mask_loss: 0.4415 - val_loss: 2.5309 - val_rpn_class_loss: 0.0919 - val_rpn_bbox_loss: 0.9432 - val_mrcnn_class_loss: 0.1980 - val_mrcnn_bbox_loss: 0.7095 - val_mrcnn_mask_loss: 0.5882
# Epoch 6/50
# 500/500 [==============================] - 2253s 5s/step - loss: 2.0821 - rpn_class_loss: 0.0820 - rpn_bbox_loss: 0.9471 - mrcnn_class_loss: 0.2044 - mrcnn_bbox_loss: 0.4561 - mrcnn_mask_loss: 0.3925 - val_loss: 2.2315 - val_rpn_class_loss: 0.0496 - val_rpn_bbox_loss: 0.8224 - val_mrcnn_class_loss: 0.3078 - val_mrcnn_bbox_loss: 0.4649 - val_mrcnn_mask_loss: 0.5868
# Epoch 7/50
# 500/500 [==============================] - 2257s 5s/step - loss: 2.2873 - rpn_class_loss: 0.0831 - rpn_bbox_loss: 1.0061 - mrcnn_class_loss: 0.2122 - mrcnn_bbox_loss: 0.5307 - mrcnn_mask_loss: 0.4550 - val_loss: 2.8211 - val_rpn_class_loss: 0.0798 - val_rpn_bbox_loss: 1.2426 - val_mrcnn_class_loss: 0.3535 - val_mrcnn_bbox_loss: 0.6207 - val_mrcnn_mask_loss: 0.5246
# Epoch 8/50
# 500/500 [==============================] - 2257s 5s/step - loss: 2.2212 - rpn_class_loss: 0.0867 - rpn_bbox_loss: 0.9695 - mrcnn_class_loss: 0.2453 - mrcnn_bbox_loss: 0.4874 - mrcnn_mask_loss: 0.4322 - val_loss: 1.7765 - val_rpn_class_loss: 0.0567 - val_rpn_bbox_loss: 0.4539 - val_mrcnn_class_loss: 0.3483 - val_mrcnn_bbox_loss: 0.4311 - val_mrcnn_mask_loss: 0.4866
# Epoch 9/50
# 500/500 [==============================] - 2251s 5s/step - loss: 2.1779 - rpn_class_loss: 0.0782 - rpn_bbox_loss: 0.9246 - mrcnn_class_loss: 0.2486 - mrcnn_bbox_loss: 0.4748 - mrcnn_mask_loss: 0.4516 - val_loss: 2.1982 - val_rpn_class_loss: 0.0404 - val_rpn_bbox_loss: 0.8340 - val_mrcnn_class_loss: 0.4546 - val_mrcnn_bbox_loss: 0.4646 - val_mrcnn_mask_loss: 0.4047
# Epoch 10/50
# 500/500 [==============================] - 2253s 5s/step - loss: 2.2226 - rpn_class_loss: 0.0738 - rpn_bbox_loss: 0.9759 - mrcnn_class_loss: 0.2346 - mrcnn_bbox_loss: 0.4952 - mrcnn_mask_loss: 0.4431 - val_loss: 1.8930 - val_rpn_class_loss: 0.0301 - val_rpn_bbox_loss: 0.6606 - val_mrcnn_class_loss: 0.2729 - val_mrcnn_bbox_loss: 0.4858 - val_mrcnn_mask_loss: 0.4436
# Epoch 11/50
# 500/500 [==============================] - 2255s 5s/step - loss: 2.1878 - rpn_class_loss: 0.0704 - rpn_bbox_loss: 0.9192 - mrcnn_class_loss: 0.2557 - mrcnn_bbox_loss: 0.4896 - mrcnn_mask_loss: 0.4530 - val_loss: 2.4288 - val_rpn_class_loss: 0.0542 - val_rpn_bbox_loss: 0.9538 - val_mrcnn_class_loss: 0.3816 - val_mrcnn_bbox_loss: 0.5597 - val_mrcnn_mask_loss: 0.4796
# Epoch 12/50
# 500/500 [==============================] - 2262s 5s/step - loss: 2.1843 - rpn_class_loss: 0.0816 - rpn_bbox_loss: 0.9516 - mrcnn_class_loss: 0.2532 - mrcnn_bbox_loss: 0.4817 - mrcnn_mask_loss: 0.4162 - val_loss: 2.6569 - val_rpn_class_loss: 0.0451 - val_rpn_bbox_loss: 0.8648 - val_mrcnn_class_loss: 0.3273 - val_mrcnn_bbox_loss: 0.8477 - val_mrcnn_mask_loss: 0.5720
# Epoch 13/50
# 500/500 [==============================] - 2254s 5s/step - loss: 2.2110 - rpn_class_loss: 0.0741 - rpn_bbox_loss: 0.9404 - mrcnn_class_loss: 0.2598 - mrcnn_bbox_loss: 0.4920 - mrcnn_mask_loss: 0.4447 - val_loss: 2.2268 - val_rpn_class_loss: 0.0401 - val_rpn_bbox_loss: 1.0625 - val_mrcnn_class_loss: 0.2469 - val_mrcnn_bbox_loss: 0.4167 - val_mrcnn_mask_loss: 0.4605
# Epoch 14/50
# 500/500 [==============================] - 2256s 5s/step - loss: 2.1390 - rpn_class_loss: 0.0755 - rpn_bbox_loss: 0.9372 - mrcnn_class_loss: 0.2821 - mrcnn_bbox_loss: 0.4447 - mrcnn_mask_loss: 0.3995 - val_loss: 2.6879 - val_rpn_class_loss: 0.0511 - val_rpn_bbox_loss: 1.1119 - val_mrcnn_class_loss: 0.4130 - val_mrcnn_bbox_loss: 0.6422 - val_mrcnn_mask_loss: 0.4697
# Epoch 15/50
# 500/500 [==============================] - 2254s 5s/step - loss: 2.2123 - rpn_class_loss: 0.0766 - rpn_bbox_loss: 0.9353 - mrcnn_class_loss: 0.2523 - mrcnn_bbox_loss: 0.4992 - mrcnn_mask_loss: 0.4489 - val_loss: 2.5295 - val_rpn_class_loss: 0.0710 - val_rpn_bbox_loss: 0.9223 - val_mrcnn_class_loss: 0.4810 - val_mrcnn_bbox_loss: 0.5707 - val_mrcnn_mask_loss: 0.4844
# Epoch 16/50
# 500/500 [==============================] - 2260s 5s/step - loss: 2.1043 - rpn_class_loss: 0.0719 - rpn_bbox_loss: 0.8307 - mrcnn_class_loss: 0.2862 - mrcnn_bbox_loss: 0.4820 - mrcnn_mask_loss: 0.4336 - val_loss: 1.8952 - val_rpn_class_loss: 0.0770 - val_rpn_bbox_loss: 0.7489 - val_mrcnn_class_loss: 0.3168 - val_mrcnn_bbox_loss: 0.3637 - val_mrcnn_mask_loss: 0.3887
# Epoch 17/50
# 500/500 [==============================] - 2256s 5s/step - loss: 2.0335 - rpn_class_loss: 0.0698 - rpn_bbox_loss: 0.8828 - mrcnn_class_loss: 0.2406 - mrcnn_bbox_loss: 0.4261 - mrcnn_mask_loss: 0.4141 - val_loss: 2.2390 - val_rpn_class_loss: 0.0465 - val_rpn_bbox_loss: 0.8337 - val_mrcnn_class_loss: 0.3996 - val_mrcnn_bbox_loss: 0.4866 - val_mrcnn_mask_loss: 0.4727
# Epoch 18/50
# 500/500 [==============================] - 2257s 5s/step - loss: 2.1109 - rpn_class_loss: 0.0746 - rpn_bbox_loss: 0.8816 - mrcnn_class_loss: 0.2587 - mrcnn_bbox_loss: 0.4503 - mrcnn_mask_loss: 0.4456 - val_loss: 2.2637 - val_rpn_class_loss: 0.0720 - val_rpn_bbox_loss: 0.8666 - val_mrcnn_class_loss: 0.3100 - val_mrcnn_bbox_loss: 0.5360 - val_mrcnn_mask_loss: 0.4791
# Epoch 19/50
# 500/500 [==============================] - 2253s 5s/step - loss: 2.0890 - rpn_class_loss: 0.0711 - rpn_bbox_loss: 0.9130 - mrcnn_class_loss: 0.2481 - mrcnn_bbox_loss: 0.4436 - mrcnn_mask_loss: 0.4132 - val_loss: 2.2768 - val_rpn_class_loss: 0.0550 - val_rpn_bbox_loss: 0.9146 - val_mrcnn_class_loss: 0.2656 - val_mrcnn_bbox_loss: 0.5743 - val_mrcnn_mask_loss: 0.4673
# Epoch 20/50
# 500/500 [==============================] - 2258s 5s/step - loss: 2.1082 - rpn_class_loss: 0.0652 - rpn_bbox_loss: 0.9085 - mrcnn_class_loss: 0.2708 - mrcnn_bbox_loss: 0.4439 - mrcnn_mask_loss: 0.4198 - val_loss: 1.9476 - val_rpn_class_loss: 0.0907 - val_rpn_bbox_loss: 0.7080 - val_mrcnn_class_loss: 0.3221 - val_mrcnn_bbox_loss: 0.4042 - val_mrcnn_mask_loss: 0.4226
# Epoch 21/50
# 500/500 [==============================] - 2261s 5s/step - loss: 2.1135 - rpn_class_loss: 0.0686 - rpn_bbox_loss: 0.9243 - mrcnn_class_loss: 0.2743 - mrcnn_bbox_loss: 0.4315 - mrcnn_mask_loss: 0.4148 - val_loss: 2.2803 - val_rpn_class_loss: 0.0792 - val_rpn_bbox_loss: 0.9405 - val_mrcnn_class_loss: 0.4768 - val_mrcnn_bbox_loss: 0.4322 - val_mrcnn_mask_loss: 0.3515
# Epoch 22/50
# 500/500 [==============================] - 2257s 5s/step - loss: 2.1409 - rpn_class_loss: 0.0640 - rpn_bbox_loss: 0.9147 - mrcnn_class_loss: 0.2843 - mrcnn_bbox_loss: 0.4568 - mrcnn_mask_loss: 0.4212 - val_loss: 2.3997 - val_rpn_class_loss: 0.0452 - val_rpn_bbox_loss: 1.2771 - val_mrcnn_class_loss: 0.0826 - val_mrcnn_bbox_loss: 0.6225 - val_mrcnn_mask_loss: 0.3723
# Epoch 23/50
# 500/500 [==============================] - 2261s 5s/step - loss: 2.1269 - rpn_class_loss: 0.0630 - rpn_bbox_loss: 0.9194 - mrcnn_class_loss: 0.2574 - mrcnn_bbox_loss: 0.4639 - mrcnn_mask_loss: 0.4231 - val_loss: 2.8091 - val_rpn_class_loss: 0.0780 - val_rpn_bbox_loss: 1.0843 - val_mrcnn_class_loss: 0.4522 - val_mrcnn_bbox_loss: 0.7172 - val_mrcnn_mask_loss: 0.4773
# Epoch 24/50
# 500/500 [==============================] - 2254s 5s/step - loss: 2.0911 - rpn_class_loss: 0.0751 - rpn_bbox_loss: 0.8667 - mrcnn_class_loss: 0.2735 - mrcnn_bbox_loss: 0.4484 - mrcnn_mask_loss: 0.4274 - val_loss: 1.9634 - val_rpn_class_loss: 0.0565 - val_rpn_bbox_loss: 0.6642 - val_mrcnn_class_loss: 0.3223 - val_mrcnn_bbox_loss: 0.4841 - val_mrcnn_mask_loss: 0.4363
# Epoch 25/50
# 500/500 [==============================] - 2258s 5s/step - loss: 2.0617 - rpn_class_loss: 0.0715 - rpn_bbox_loss: 0.8534 - mrcnn_class_loss: 0.2921 - mrcnn_bbox_loss: 0.4274 - mrcnn_mask_loss: 0.4173 - val_loss: 2.9666 - val_rpn_class_loss: 0.1391 - val_rpn_bbox_loss: 1.1589 - val_mrcnn_class_loss: 0.1622 - val_mrcnn_bbox_loss: 0.8685 - val_mrcnn_mask_loss: 0.6379
# Epoch 26/50
# 500/500 [==============================] - 2257s 5s/step - loss: 2.1558 - rpn_class_loss: 0.0716 - rpn_bbox_loss: 0.8760 - mrcnn_class_loss: 0.3017 - mrcnn_bbox_loss: 0.4604 - mrcnn_mask_loss: 0.4461 - val_loss: 2.3516 - val_rpn_class_loss: 0.0536 - val_rpn_bbox_loss: 0.8845 - val_mrcnn_class_loss: 0.3151 - val_mrcnn_bbox_loss: 0.5519 - val_mrcnn_mask_loss: 0.5466
# Epoch 27/50
# 500/500 [==============================] - 2254s 5s/step - loss: 2.0395 - rpn_class_loss: 0.0596 - rpn_bbox_loss: 0.8418 - mrcnn_class_loss: 0.2619 - mrcnn_bbox_loss: 0.4460 - mrcnn_mask_loss: 0.4301 - val_loss: 2.2918 - val_rpn_class_loss: 0.0412 - val_rpn_bbox_loss: 0.9945 - val_mrcnn_class_loss: 0.2632 - val_mrcnn_bbox_loss: 0.5597 - val_mrcnn_mask_loss: 0.4331
# Epoch 28/50
# 500/500 [==============================] - 2259s 5s/step - loss: 2.0524 - rpn_class_loss: 0.0744 - rpn_bbox_loss: 0.8315 - mrcnn_class_loss: 0.2670 - mrcnn_bbox_loss: 0.4447 - mrcnn_mask_loss: 0.4349 - val_loss: 1.7307 - val_rpn_class_loss: 0.0400 - val_rpn_bbox_loss: 0.5582 - val_mrcnn_class_loss: 0.3552 - val_mrcnn_bbox_loss: 0.4037 - val_mrcnn_mask_loss: 0.3736
# Epoch 29/50
# 500/500 [==============================] - 2261s 5s/step - loss: 2.0092 - rpn_class_loss: 0.0715 - rpn_bbox_loss: 0.8838 - mrcnn_class_loss: 0.2657 - mrcnn_bbox_loss: 0.4073 - mrcnn_mask_loss: 0.3810 - val_loss: 2.5715 - val_rpn_class_loss: 0.0747 - val_rpn_bbox_loss: 2.2184 - val_mrcnn_class_loss: 0.0069 - val_mrcnn_bbox_loss: 0.1544 - val_mrcnn_mask_loss: 0.1171
# Epoch 30/50
# 500/500 [==============================] - 2259s 5s/step - loss: 2.0093 - rpn_class_loss: 0.0709 - rpn_bbox_loss: 0.8274 - mrcnn_class_loss: 0.2672 - mrcnn_bbox_loss: 0.4294 - mrcnn_mask_loss: 0.4143 - val_loss: 2.9208 - val_rpn_class_loss: 0.0639 - val_rpn_bbox_loss: 1.7543 - val_mrcnn_class_loss: 0.3277 - val_mrcnn_bbox_loss: 0.4163 - val_mrcnn_mask_loss: 0.3585
# Epoch 31/50
# 500/500 [==============================] - 2257s 5s/step - loss: 2.1160 - rpn_class_loss: 0.0642 - rpn_bbox_loss: 0.8981 - mrcnn_class_loss: 0.2893 - mrcnn_bbox_loss: 0.4443 - mrcnn_mask_loss: 0.4202 - val_loss: 2.7744 - val_rpn_class_loss: 0.0767 - val_rpn_bbox_loss: 1.6498 - val_mrcnn_class_loss: 0.0618 - val_mrcnn_bbox_loss: 0.6430 - val_mrcnn_mask_loss: 0.3431
# Epoch 32/50
# 500/500 [==============================] - 2255s 5s/step - loss: 2.1307 - rpn_class_loss: 0.0664 - rpn_bbox_loss: 0.8592 - mrcnn_class_loss: 0.2847 - mrcnn_bbox_loss: 0.4795 - mrcnn_mask_loss: 0.4410 - val_loss: 2.9805 - val_rpn_class_loss: 0.0613 - val_rpn_bbox_loss: 1.5593 - val_mrcnn_class_loss: 0.1141 - val_mrcnn_bbox_loss: 0.7514 - val_mrcnn_mask_loss: 0.4945
# Epoch 33/50
# 500/500 [==============================] - 2259s 5s/step - loss: 2.0397 - rpn_class_loss: 0.0668 - rpn_bbox_loss: 0.8525 - mrcnn_class_loss: 0.2718 - mrcnn_bbox_loss: 0.4386 - mrcnn_mask_loss: 0.4100 - val_loss: 1.7567 - val_rpn_class_loss: 0.0829 - val_rpn_bbox_loss: 0.6299 - val_mrcnn_class_loss: 0.2572 - val_mrcnn_bbox_loss: 0.4033 - val_mrcnn_mask_loss: 0.3833
# Epoch 34/50
# 500/500 [==============================] - 2262s 5s/step - loss: 2.0504 - rpn_class_loss: 0.0708 - rpn_bbox_loss: 0.8432 - mrcnn_class_loss: 0.2927 - mrcnn_bbox_loss: 0.4276 - mrcnn_mask_loss: 0.4161 - val_loss: 2.3361 - val_rpn_class_loss: 0.0428 - val_rpn_bbox_loss: 1.1775 - val_mrcnn_class_loss: 0.2696 - val_mrcnn_bbox_loss: 0.4759 - val_mrcnn_mask_loss: 0.3703
# Epoch 35/50
# 500/500 [==============================] - 2260s 5s/step - loss: 2.0908 - rpn_class_loss: 0.0766 - rpn_bbox_loss: 0.8750 - mrcnn_class_loss: 0.2917 - mrcnn_bbox_loss: 0.4382 - mrcnn_mask_loss: 0.4093 - val_loss: 2.3687 - val_rpn_class_loss: 0.1184 - val_rpn_bbox_loss: 0.8911 - val_mrcnn_class_loss: 0.3642 - val_mrcnn_bbox_loss: 0.5597 - val_mrcnn_mask_loss: 0.4353
# Epoch 36/50
# 500/500 [==============================] - 2259s 5s/step - loss: 2.0108 - rpn_class_loss: 0.0561 - rpn_bbox_loss: 0.8184 - mrcnn_class_loss: 0.2616 - mrcnn_bbox_loss: 0.4460 - mrcnn_mask_loss: 0.4287 - val_loss: 2.1224 - val_rpn_class_loss: 0.0691 - val_rpn_bbox_loss: 0.7981 - val_mrcnn_class_loss: 0.3982 - val_mrcnn_bbox_loss: 0.4243 - val_mrcnn_mask_loss: 0.4327
# Epoch 37/50
# 500/500 [==============================] - 2257s 5s/step - loss: 1.9764 - rpn_class_loss: 0.0678 - rpn_bbox_loss: 0.8293 - mrcnn_class_loss: 0.2629 - mrcnn_bbox_loss: 0.4212 - mrcnn_mask_loss: 0.3953 - val_loss: 3.0180 - val_rpn_class_loss: 0.0581 - val_rpn_bbox_loss: 1.5815 - val_mrcnn_class_loss: 0.5206 - val_mrcnn_bbox_loss: 0.4025 - val_mrcnn_mask_loss: 0.4554
# Epoch 38/50
# 500/500 [==============================] - 2261s 5s/step - loss: 2.0993 - rpn_class_loss: 0.0784 - rpn_bbox_loss: 0.8748 - mrcnn_class_loss: 0.2925 - mrcnn_bbox_loss: 0.4425 - mrcnn_mask_loss: 0.4112 - val_loss: 1.4675 - val_rpn_class_loss: 0.0405 - val_rpn_bbox_loss: 0.5008 - val_mrcnn_class_loss: 0.2477 - val_mrcnn_bbox_loss: 0.3069 - val_mrcnn_mask_loss: 0.3716
# Epoch 39/50
# 500/500 [==============================] - 2256s 5s/step - loss: 2.0809 - rpn_class_loss: 0.0621 - rpn_bbox_loss: 0.8963 - mrcnn_class_loss: 0.2823 - mrcnn_bbox_loss: 0.4234 - mrcnn_mask_loss: 0.4168 - val_loss: 1.4847 - val_rpn_class_loss: 0.0607 - val_rpn_bbox_loss: 1.0573 - val_mrcnn_class_loss: 0.0811 - val_mrcnn_bbox_loss: 0.1092 - val_mrcnn_mask_loss: 0.1764
# Epoch 40/50
# 500/500 [==============================] - 2260s 5s/step - loss: 1.9295 - rpn_class_loss: 0.0571 - rpn_bbox_loss: 0.7873 - mrcnn_class_loss: 0.2673 - mrcnn_bbox_loss: 0.4171 - mrcnn_mask_loss: 0.4007 - val_loss: 2.1017 - val_rpn_class_loss: 0.0853 - val_rpn_bbox_loss: 1.1174 - val_mrcnn_class_loss: 0.1463 - val_mrcnn_bbox_loss: 0.4288 - val_mrcnn_mask_loss: 0.3240
# Epoch 41/50
# 500/500 [==============================] - 2267s 5s/step - loss: 2.1310 - rpn_class_loss: 0.0725 - rpn_bbox_loss: 0.8678 - mrcnn_class_loss: 0.3172 - mrcnn_bbox_loss: 0.4438 - mrcnn_mask_loss: 0.4298 - val_loss: 1.9118 - val_rpn_class_loss: 0.0379 - val_rpn_bbox_loss: 0.7037 - val_mrcnn_class_loss: 0.3358 - val_mrcnn_bbox_loss: 0.4451 - val_mrcnn_mask_loss: 0.3892
# Epoch 42/50
# 500/500 [==============================] - 2259s 5s/step - loss: 2.1025 - rpn_class_loss: 0.0653 - rpn_bbox_loss: 0.8637 - mrcnn_class_loss: 0.2968 - mrcnn_bbox_loss: 0.4526 - mrcnn_mask_loss: 0.4241 - val_loss: 2.1610 - val_rpn_class_loss: 0.0551 - val_rpn_bbox_loss: 0.8394 - val_mrcnn_class_loss: 0.4007 - val_mrcnn_bbox_loss: 0.4469 - val_mrcnn_mask_loss: 0.4189
# Epoch 43/50
# 500/500 [==============================] - 2265s 5s/step - loss: 2.0660 - rpn_class_loss: 0.0645 - rpn_bbox_loss: 0.8544 - mrcnn_class_loss: 0.2856 - mrcnn_bbox_loss: 0.4428 - mrcnn_mask_loss: 0.4187 - val_loss: 1.8626 - val_rpn_class_loss: 0.0334 - val_rpn_bbox_loss: 0.7222 - val_mrcnn_class_loss: 0.3302 - val_mrcnn_bbox_loss: 0.3934 - val_mrcnn_mask_loss: 0.3835
# Epoch 44/50
# 500/500 [==============================] - 2262s 5s/step - loss: 2.0665 - rpn_class_loss: 0.0594 - rpn_bbox_loss: 0.9103 - mrcnn_class_loss: 0.2529 - mrcnn_bbox_loss: 0.4332 - mrcnn_mask_loss: 0.4106 - val_loss: 1.3712 - val_rpn_class_loss: 0.0138 - val_rpn_bbox_loss: 0.6666 - val_mrcnn_class_loss: 0.0613 - val_mrcnn_bbox_loss: 0.2842 - val_mrcnn_mask_loss: 0.3453
# Epoch 45/50
# 500/500 [==============================] - 2261s 5s/step - loss: 1.9764 - rpn_class_loss: 0.0649 - rpn_bbox_loss: 0.8556 - mrcnn_class_loss: 0.2636 - mrcnn_bbox_loss: 0.3991 - mrcnn_mask_loss: 0.3931 - val_loss: 1.4450 - val_rpn_class_loss: 0.0235 - val_rpn_bbox_loss: 0.5080 - val_mrcnn_class_loss: 0.1426 - val_mrcnn_bbox_loss: 0.4352 - val_mrcnn_mask_loss: 0.3357
# Epoch 46/50
# 500/500 [==============================] - 2259s 5s/step - loss: 2.0468 - rpn_class_loss: 0.0677 - rpn_bbox_loss: 0.8328 - mrcnn_class_loss: 0.2782 - mrcnn_bbox_loss: 0.4403 - mrcnn_mask_loss: 0.4277 - val_loss: 1.8417 - val_rpn_class_loss: 0.1146 - val_rpn_bbox_loss: 0.6532 - val_mrcnn_class_loss: 0.3147 - val_mrcnn_bbox_loss: 0.3599 - val_mrcnn_mask_loss: 0.3993
# Epoch 47/50
# 500/500 [==============================] - 2263s 5s/step - loss: 2.0542 - rpn_class_loss: 0.0672 - rpn_bbox_loss: 0.8528 - mrcnn_class_loss: 0.2486 - mrcnn_bbox_loss: 0.4518 - mrcnn_mask_loss: 0.4338 - val_loss: 2.2584 - val_rpn_class_loss: 0.1167 - val_rpn_bbox_loss: 0.9797 - val_mrcnn_class_loss: 0.1856 - val_mrcnn_bbox_loss: 0.4995 - val_mrcnn_mask_loss: 0.4768
# Epoch 48/50
# 500/500 [==============================] - 2258s 5s/step - loss: 1.9948 - rpn_class_loss: 0.0672 - rpn_bbox_loss: 0.8156 - mrcnn_class_loss: 0.2717 - mrcnn_bbox_loss: 0.4253 - mrcnn_mask_loss: 0.4149 - val_loss: 2.8239 - val_rpn_class_loss: 0.0416 - val_rpn_bbox_loss: 1.3525 - val_mrcnn_class_loss: 0.0920 - val_mrcnn_bbox_loss: 0.9049 - val_mrcnn_mask_loss: 0.4329
# Epoch 49/50
# 500/500 [==============================] - 2260s 5s/step - loss: 2.1006 - rpn_class_loss: 0.0641 - rpn_bbox_loss: 0.8867 - mrcnn_class_loss: 0.2827 - mrcnn_bbox_loss: 0.4472 - mrcnn_mask_loss: 0.4198 - val_loss: 1.9089 - val_rpn_class_loss: 0.0531 - val_rpn_bbox_loss: 0.6186 - val_mrcnn_class_loss: 0.4051 - val_mrcnn_bbox_loss: 0.4223 - val_mrcnn_mask_loss: 0.4098
# Epoch 50/50
# 500/500 [==============================] - 2262s 5s/step - loss: 2.0945 - rpn_class_loss: 0.0651 - rpn_bbox_loss: 0.8643 - mrcnn_class_loss: 0.3022 - mrcnn_bbox_loss: 0.4314 - mrcnn_mask_loss: 0.4315 - val_loss: 2.1228 - val_rpn_class_loss: 0.0439 - val_rpn_bbox_loss: 0.9263 - val_mrcnn_class_loss: 0.3716 - val_mrcnn_bbox_loss: 0.4202 - val_mrcnn_mask_loss: 0.3608
# Training took 1882.12 minutes

# %%
# Fine tune all layers
# Passing layers="all" trains all layers. You can also 
# pass a regular expression to select which layers to
# train by name pattern.
start_train = time.time()
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE / 10,
            epochs=10, 
            layers="all")
end_train = time.time()
minutes = round((end_train - start_train) / 60, 2)
print(f'Training took {minutes} minutes')
# Out:
# Starting at epoch 50. LR=0.0001
#
# Checkpoint Path: logs/coco_text20190313T2147/mask_rcnn_coco_text_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Training took 0.29 minutes

# %% [markdown]
# # Prepare to run Inference
# Create a new InferenceConfig, then use it to create a new model.

# %%
class InferenceConfig(CigButtsConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1
    IMAGE_MIN_DIM = 512
    IMAGE_MAX_DIM = 512
    DETECTION_MIN_CONFIDENCE = 0.85
    

inference_config = InferenceConfig()

# %%
# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=MODEL_DIR)
# Out:
# WARNING:tensorflow:From /home/cruigo/.local/lib/python3.6/site-packages/tensorflow/python/ops/sparse_ops.py:1165: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.

# %%
# Get path to saved weights
# Either set a specific path or find last trained weights
# model_path = os.path.join(ROOT_DIR, ".h5 file name here")
model_path = model.find_last()

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  logs/coco_text20190313T2147/mask_rcnn_coco_text_0050.h5
# Re-starting from epoch 50

# %% [markdown]
# # Run Inference
# Run model.detect() on real images.
#
# We get some false positives, and some misses. More training images are likely needed to improve the results.

# %%
import skimage
real_test_dir = 'test2014'
image_paths = []
for filename in os.listdir(real_test_dir):
    if os.path.splitext(filename)[1].lower() in ['.png', '.jpg', '.jpeg']:
        image_paths.append(os.path.join(real_test_dir, filename))

for image_path in image_paths[20:30]:
    img = skimage.io.imread(image_path)
    img_arr = np.array(img)
    results = model.detect([img_arr], verbose=1)
    r = results[0]
    visualize.display_instances(img, r['rois'], r['masks'], r['class_ids'], 
                                dataset_val.class_names, r['scores'], figsize=(5,5))
# Out:
# Processing 1 images
# image                    shape: (480, 640, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  640.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (480, 640, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  640.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
#
# *** No instances to display ***
# Processing 1 images
# image                    shape: (640, 361, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  640.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (480, 640, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  640.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (360, 640, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  146.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  640.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (423, 640, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  640.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (427, 640, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  149.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  640.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (318, 640, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  640.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (427, 640, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  146.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  640.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
#
# *** No instances to display ***
# Processing 1 images
# image                    shape: (479, 640, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  640.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
